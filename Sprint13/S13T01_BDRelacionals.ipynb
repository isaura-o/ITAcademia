# %% [markdown]
# $\#\#\#\#\#\#\#$ Libraries $\#\#\#\#\#\#\#$

# %% [markdown]
# Programs used:
#
# - diagram.de
# - Workbench MySQL

# %% [markdown]
# $\#\#\#\#\#\#\#\#\#\#\#\#\#\#\#\#\#\#\#\#\#\#$

# %% [markdown]
# In this task we have done "by hand" the first exercise. In this case we have choose to show the two different types of diagrams, for the first part we have used the "entity-relation" diagram, with Chen's notation, but without weigthing the relationships since it was meant to be an skecth. The second part we have choose to use the relation diagram for practicallity, although we have used Chen's Notation to show the relationships between entities and relations, since as before it was to be meant to be an sketch.
#
# These diagrams have two types of notations: Chen's notation and Crow's notation[1](https://www.conceptdraw.com/examples/erd-weak-entity). The Chen's notations is what we have used in exercise 2, with the diagram drawer. And the Crow's notations is done in exercise 3, with the MySQL Workshop.
#
# ![Entity-Relationship-Diagram-Symbols.jpg](attachment:Entity-Relationship-Diagram-Symbols.jpg)
#
# This image is from: https://www.conceptdraw.com/examples/erd-weak-entity

# %% [markdown]
# # Nivell 1

# %% [markdown]
# ## Exercici 1: Crea una base relacional d’exemple utilitzant un document de text o a mà. Dissenya-la perquè contingui les següents taules, i estableix les relacions que consideris necessàries entre elles:
#
#
# -	**Taula de compres (transaccions)**
#
# -	**Taula d’establiments**
#
# -	**Taula de treballadors**
#
# -	**Taula de clients**
#
# -	**Taula de productes**
#
# -	**Taula de tipus de productes**

# %% [markdown]
# The following figure shows a the diagram of relational base that contains: Clients, Orders (compres), Employees (workers), Establishment, products, and, products types.
#
# For this exercise we have choose, first, to show the diagram entity-relation, and then, since they are asking for the information on each table, we will use the typical "table diagram", like the one at the end of this [page](https://www.chrisbell.com/SNHU/IT-510-Advanced-Information-Technology/database-management-system-DBMS-relationships.php).
#
# The **squares** in the diagram are the **Entities**, the **circles** are the **Attributes**. This is why in this case, since product type is a table which contains the description of the products, we use the circle for product type and the square for product.
#
# The **diamond** shape is reserved for the attributes that **interrelate** two or more entities. In this case we have two tables that are able to interrelate: Order and Establishment. Also, we need to noticies that not only they can iterrelate entities also,they are permitted to interrelate with another interrelational table.

# %% [markdown]
# ![diagramW.png](attachment:diagramW.png)

# %% [markdown]
# Looking at the figure above, we have concluded that client, products, and, employees are by themselves entities. Because each one of these contains a number of attributes like we see in the case of product that have the attribute product type, which is an attribute multivaluated, since may contain the product name, brand, description, etc. (we will see this in the next part). The three entities: client, products, and, employees are related between themselves with the interrelational table order, this is because on each order we have the clientID, the productsID and the employeeID. Also, in the order we have the establishmentID, which relates the two interrelational tables. And, for the table establishment we realize that in the tables product and employees, establishmentID is an attribute also of their table.

# %% [markdown]
# ## Defineix les propietats de les relacions (1:1, 1:n, n:n), i crea algunes de les variables que podrien contenir, per exemple:
#
#
# ## Taula d’establiments
#
# -	IDestabliment (unique key)
#
# -	Nom
#
# -	Localització
#
# -	Superfície

# %% [markdown]
# Now, let's characterize each table with its attributes, we also will draw their property relations: 1:1, 1:n, and, n:n. To do, so instead of using the diagram like before, it is more confortable use the Relational Diagram, but we will be using Chen's notation from the ER diagrams, like the one it follows, because of the large number of attributes.

# %% [markdown]
# ![tableDiagr.png](attachment:tableDiagr.png)

# %% [markdown]
# In this figure, we can see that inside that each entity/attribute we have write some attributes that belong to their parent table, and also that may belong to a another entity/attribute if the attribute it is multivaluated. Single head arrows mean that the relation is 1:1, while double headed arrows mean that the relation 1:n. For n:n we also have used double headed double arrows.
# Also, we have write down the relationships of the tables.
#
# - The relationship between clients and orders it is 1:n, since a client may place multiple orders.
#   We have choose for clients the attributes: Name, Last Name, Address 1, Address 2 (if more addresses are needed), and, phone number.
#
# - The products to orders it is n:n, since multiple orders can have multiple products.
#   We have choose for products the attributes: Item_ID, Establishment_ID, Unit price.
#
# - The establishments-employees it is 1:1, the first, since each employee it is on one establishment, while it is 1:n for establishment-product, since a product may be in more than one establishment, the same for establishment-order, we can have more than one order in one establishment.
#   We have choose for establishment: Name, Address, Phone number, and, surface. For Employees: Name, Last Name, Title, and, work phone number. And for Order: Client_ID, Employee_ID, Establishment_ID, Product_ID, Quantity, and, Total Price.
#
# - The products-product type is a 1:1, since each item has specific description, brand, etc.
#   For product type: Name Product, brand, and, description of the item.

# %% [markdown]
# # Nivell 2

# %% [markdown]
# ## Exercici 2 : Utilitza un programa de creació de diagrames entitat-relació com http://dia-installer.de per crear el diagrama.

# %% [markdown]
# Entity-relation diagrams are like the one we have show in the first part of exercise 1. Now, we use the program above to make the representation.

# %% [markdown]
# ![Diagrama1.jpeg](attachment:Diagrama1.jpeg)

# %% [markdown]
# This figure is similar to the ones hand written, but we have also add the attributes to each entity. The attributes are in light blue, the key attributes are in a darker light blue. The entities are in green, while the relational entities are in purple. The relational numbers 1:1, 1:n, n:n are written in the relational entities.

# %% [markdown]
# This figure above is analogous to the figure done by hand, but instead we used diaw.exe to draw it.

# %% [markdown]
# # Nivell 3

# %% [markdown]
# ## Exercici 3: Utilitza el Workbench de MySQL per crear un model relacional.

# %% [markdown]
# Relational model are the "table diagrams", and we use the workbench of MySQL to do the figure.

# %% [markdown]
# ![diagramsql.jpg](attachment:diagramsql.jpg)

# %% [markdown]
# We can notice that the connection between the Establishment and Order is not in the figure, this is because we can see that the Employees has the establishment primary key and they are in the Order as: Employees_Establishemnt_ID, thus the connection we draw on the other figures was not necessary.
#
# Also, we have a new "table", that it is called: Orders has products, this is consequence of the orders may have many products, i.e., a many-to-many connection.
