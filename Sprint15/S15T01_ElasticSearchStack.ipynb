# %% [markdown]
# $\#\#\#\#\#\#\#$ Libraries $\#\#\#\#\#\#\#$

# %% [markdown]
# Kibana Cloud

# %% [markdown]
# $\#\#\#\#\#\#\#\#\#\#\#\#\#\#\#\#\#\#\#\#\#\#$

# %% [markdown]
# ## Data

# %% [markdown]
# The dataset choosen for this sprint ilustrates how change the temperatures because of the [Climate Change](https://www.kaggle.com/datasets/sevgisarac/temperature-change).
#
# The dataset it is comprised of 66 features.
#
# - Area: in which the temperature was taken and numerical value associated.
# - Months: in which the value was taken (January to December) or trimester (i.e., December-January-February) or if the temperature difference it is yearly taken.
# - Unit: feature which indicates that the difference of temperature was taken in Centigrads.
# - The rest of columns are the observations of difference of temperature of the years from 1961 to 2019.

# %% [markdown]
# # Nivell 1

# %% [markdown]
# ## Exercici 1: Descarrega't Kibana i mostra algunes gràfiques utilitzant conjunts de dades d'Exemple.

# %% [markdown]
# ![climatechange60s.PNG](attachment:climatechange60s.PNG)

# %% [markdown]
# ![climatechange2k10s.PNG](attachment:climatechange2k10s.PNG)

# %% [markdown]
# These graphs shows the minimum and maximum temperatures of some countries around the world during the decade of the 60s and 2k10s. We can see that in the top graph, the minimum values are lower than in the bottom graph, and also the maximum values are also lower. Meaning that during the 60s the temperature in these countries was lower consistently during all the year. In the other hand, in the decade of the 2k10s the temperature around the globe it is higher, we can see that this also applies to the minimum temperatures, where some countries were to able to have low temperature differences of -8 degrees celsium on the 60s, in the 2k10s these are around -5 Celsium.

# %% [markdown]
# ![Dashboard%20%5B2022-05-16T10%2011%2048.789-06%2000%5D.PNG](attachment:Dashboard%20%5B2022-05-16T10%2011%2048.789-06%2000%5D.PNG)

# %% [markdown]
# ![Dashboard%20%5B2022-05-16T10%2017%2041.696-06%2000%5D.PNG](attachment:Dashboard%20%5B2022-05-16T10%2017%2041.696-06%2000%5D.PNG)

# %% [markdown]
# The two graph above are the average temperatures for each decade of the dataset (left one) and in the right hand we have for the top graph the maximum temperatures, while for the bottom graph the minimum temperatures for different countries. Again, in these two graph we can see how the temperature around the globe has increased, in the leftside graph we can see that each decade the temperature difference it is around 0.2 degrees celsius higher than the decade before. Also, the data for 2019 shows a difference of temperature of around 1.2 degrees celsius consistently across the year and across the countries represented. This it is show also in the right-hand graph in both panels, which show the minimum and maximum temperatures.

# %% [markdown]
# # Nivell 2

# %% [markdown]
# ## Exercici 1: Implementa un dashboard que visualitzi interactivament les dades que triïs.

# %% [markdown]
# The following link goes to the dashboard shown in the last exercise (image below).
#
# [LINK](https://dataset1.kb.us-central1.gcp.cloud.es.io:9243/app/r/s/grumpy-disgusting-island)
#
#
# ![climatechange.PNG](attachment:climatechange.PNG)

# %% [markdown]
# # Nivell 3

# %% [markdown]
# ## Exercici 1: Implementa un dashboard que generi gràfics utilitzant cadascun dels diferents tipus de gràfics que ofereix Kibana.

# %% [markdown]
# The following link goes to a dashboard with a further analysis of the dataset, by using more of the kibana graphs:

# %% [markdown]
# [Link](https://dataset1.kb.us-central1.gcp.cloud.es.io:9243/app/dashboards#/view/82366640-d53c-11ec-8bda-0dbbc70c3361?_g=(filters%3A!()%2CrefreshInterval%3A(pause%3A!t%2Cvalue%3A0)%2Ctime%3A(from%3Anow-15m%2Cto%3Anow)))
